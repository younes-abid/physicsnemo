# %%
#pip install streamlit==1.50.0

# %%
# ! streamlit hello

# %%
ls /app/notebooks/tutorials/cordiff/weather-pipeline/
# Out:
# Home.py  pages/

# %%
pwd
# Out:
# '/app/notebooks/tutorials/cordiff'

# %%
! streamlit run /app/notebooks/tutorials/cordiff/weather-pipeline/Home.py
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.17.0.2:8501
#   External URL: http://5.195.212.197:8501
#
# 2025-09-26 07:04:06.131 Uncaught app execution
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 667, in code_to_exec
#     _mpa_v1(self._main_script_path)
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 165, in _mpa_v1
#     page.run()
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/navigation/page.py", line 300, in run
#     exec(code, module.__dict__)  # noqa: S102
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/app/notebooks/tutorials/cordiff/weather-pipeline/Home.py", line 15, in <module>
#     st.page_link("app.py", label="Home", icon="🏠")
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/elements/widgets/button.py", line 871, in page_link
#     return self._page_link(
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/elements/widgets/button.py", line 1082, in _page_link
#     raise StreamlitPageNotFoundError(
# streamlit.errors.StreamlitPageNotFoundError: Could not find page: `app.py`. You must provide a file path relative to the entrypoint file (from the directory `weather-pipeline`). Only the entrypoint file and files in the `pages/` directory are supported.
